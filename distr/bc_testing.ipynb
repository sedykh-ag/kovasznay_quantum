# %%
from essential import *
import matplotlib.pyplot as plt

# %%
bc_u = boundary_condition_u
bc_v = boundary_condition_v
bc_p = boundary_condition_right_p

# %%
x = domain.random_boundary_points(n=1000)
pred = torch.rand(1000, 3)
exact = u_func(x)

# %%
plt.scatter(x[:, 0], x[:, 1], s=5, c=pred[:, 0])

# %%
err_u = bc_u(x, exact)

# %%
plt.scatter(x[:, 0], x[:, 1], c=err_u)
plt.colorbar()
